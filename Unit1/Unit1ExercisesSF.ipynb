# %% [markdown]
# <a href="https://colab.research.google.com/github/thedarredondo/data-science-fundamentals/blob/main/Unit1/Unit1ExercisesSF.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Unit 1 Exercises: Data Structure Concepts
#
# The following questions will ask you to describe the various objects we learned about in the first Unit.
#
# I'm not giving you coding exercises, because we will learn all the coding technqiues we need as we move through the course.
#
# What I do need from you right now, is a conceptual understanding how how data is stored in our computer, when we use python.

# %% [markdown]
# **Task1**:
#
# Describe the similarities and differences between an int and a float in python.

# %% [markdown]
# **Answer1**:
#
# *write your answer here*

# %% [markdown]
# **Task2**:
#
# Describe the similarities and differences between: strings, lists, and dicts.

# %% [markdown]
# **Answer2**:
#
# *write your answer here*

# %% [markdown]
# **Task3**:
#
# What is a numpy array? Why would we ever use one over a list or dict?

# %% [markdown]
# **Answer3**:
#
# *write your answer here*

# %% [markdown]
# **Task4**:
#
# What is a pandas dataframe? Why would we ever want to use one over a numpy array?

# %% [markdown]
# **Answer4**:
#
# *write your answer here*

# %% [markdown]
# **Task5**:
#
# What are for loops, and why would we ever use them?

# %% [markdown]
# **Answer5**:
#
# *write your answer here*

# %% [markdown]
# ## Bonus: Faster Data Wrangling
#
# No, this is not extra credit. There will never be extra credit in this class. Only do these tasks if they sound fun, to procrastinate on your other coursework.

# %% [markdown]
# I mentioned in the notes that [polars](https://docs.pola.rs/user-guide/migration/pandas/#filtering) is a library that is just plain faster than pandas. I've never actually played with it myself, so I'm shifting that responsibility over to you.

# %% [markdown]
# **Task6**
#
# Redo Task11 from the notes, but in polars.

# %% [markdown]
# **Task7**
#
# Measure how much faster polars is at the Task11 operation than pandas.

# %% [markdown]
# **Task8**:
#
# Explain, in detail, exactly why polars is faster than pandas. Is anything lost by making these changes? Is polars strictly better than pandas? If so, why would pandas exist in the first place?
#
# Remember, this is supposed to be fun. If its not, stop and doing something else.
